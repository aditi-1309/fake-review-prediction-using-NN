# %%
# One time installation of necessary libraries
#!pip install spacy
#!pip install tensorflow, keras
#!pip install nltk
#!pip install gensim

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing all necessary libraries
import pandas as pd
import numpy as np
from keras.preprocessing import sequence
from keras.layers import TimeDistributed, GlobalAveragePooling1D, GlobalAveragePooling2D, BatchNormalization
from keras.layers.recurrent import LSTM
from keras.layers.convolutional import Conv1D, MaxPooling1D, Conv2D, MaxPooling2D, AveragePooling1D
#from keras.layers.embeddings import Embedding
from keras.layers import Dropout, Flatten, Bidirectional, Dense, Activation, TimeDistributed
from keras.models import Model, Sequential
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from string import ascii_lowercase
from collections import Counter
from gensim.models import Doc2Vec
from gensim.models import doc2vec
from gensim.models import KeyedVectors
import itertools, nltk, snowballstemmer, re
from gensim.models.doc2vec import TaggedDocument
from gensim.models import KeyedVectors
nltk.download('stopwords')

TaggedDocument = doc2vec.TaggedDocument
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Reading data into a dataframe
df = pd.read_csv("/content/drive/MyDrive/Practicum/Amazon Reviews Dataset.csv")

# %%
# Converting polarity and deceptive field to binary
df['polarity'] = np.where(df['polarity']=='positive', 1, 0)
df['deceptive'] = np.where(df['deceptive']=='truthful', 1, 0)

# %%
# Classes and functions used for text vectorization
class LabeledLineSentence(object):
    def __init__(self, sources):
        self.sources = sources
        
        flipped = {}
        
        # Checking uniqueness of the key
        for key, value in sources.items():
            if value not in flipped:
                flipped[value] = [key]
            else:
                raise Exception('Non-unique prefix encountered')
    
    def __iter__(self):
        for source, prefix in self.sources.items():
            with utils.smart_open(source) as fin:
                for item_no, line in enumerate(fin):
                    yield TaggedDocument(utils.to_unicode(line).split(), [prefix + '_%s' % item_no])
    
    def to_array(self):
        self.sentences = []
        for source, prefix in self.sources.items():
            with utils.smart_open(source) as fin:
                for item_no, line in enumerate(fin):
                    self.sentences.append(TaggedDocument(utils.to_unicode(line).split(), [prefix + '_%s' % item_no]))
        return self.sentences
    
    def sentences_perm(self):
        shuffled = list(self.sentences)
        random.shuffle(shuffled)
        return shuffled

def create_class(c):
    if c['polarity'] == 1 and c['deceptive'] == 1:
        return [1,1]
    elif c['polarity'] == 1 and c['deceptive'] == 0:
        return [1,0]
    elif c['polarity'] == 0 and c['deceptive'] == 1:
        return [0,1]
    else:
        return [0,0]
    
def specific_class(c):
    if c['polarity'] == 1 and c['deceptive'] == 1:
        return "TRUE_POSITIVE"
    elif c['polarity'] == 1 and c['deceptive'] == 0:
        return "FALSE_POSITIVE"
    elif c['polarity'] == 0 and c['deceptive'] == 1:
        return "TRUE_NEGATIVE"
    else:
        return "FALSE_NEGATIVE"

df['final_class'] = df.apply(create_class, axis=1)
df['given_class'] = df.apply(specific_class, axis=1)

# %%
Y =df['final_class'].astype("string")

# Encoding class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

# Converting integers to dummy variables
dummy_y = np_utils.to_categorical(encoded_Y)

# %%
# Treating each review as a document
textData = pd.DataFrame(list(df['text']))

# %%
# Initializing stemmer
stemmer = snowballstemmer.EnglishStemmer()

# Getting stopword list
stop = stopwords.words('english')

# Extending stopword list
stop.extend(['may','also','zero','one','two','three','four','five','six','seven','eight','nine','ten','across','among','beside','however','yet','within']+list(ascii_lowercase))
stoplist = stemmer.stemWords(stop)

# Converting it into a set for later
stoplist = set(stoplist)
stop = set(sorted(stop + list(stoplist)))

# %%
# Removing characters and stoplist words
textData[0].replace('[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’”“′‘\\\]',' ',inplace=True,regex=True)

# Generating dictionary of unique words
wordlist = filter(None, " ".join(list(set(list(itertools.chain(*textData[0].str.split(' ')))))).split(" "))
df['stemmed_text_data'] = [' '.join(filter(None,filter(lambda word: word not in stop, line))) for line in textData[0].str.lower().str.split(' ')]

# %%
# Removing all words that are appearing less frequently
minimum_count = 1
str_frequencies = pd.DataFrame(list(Counter(filter(None,list(itertools.chain(*df['stemmed_text_data'].str.split(' '))))).items()),columns=['word','count'])
low_frequency_words = set(str_frequencies[str_frequencies['count'] < minimum_count]['word'])
df['stemmed_text_data'] = [' '.join(filter(None,filter(lambda word: word not in low_frequency_words, line))) for line in df['stemmed_text_data'].str.split(' ')]
df['stemmed_text_data'] = [" ".join(stemmer.stemWords(re.sub('[!"#%\'()*+,-./:;<=>?@\[\]^_`{|}~1234567890’”“′‘\\\]',' ', next_text).split(' '))) for next_text in df['stemmed_text_data']]

# %%
# Lemmatizing the text data
lmtzr = WordNetLemmatizer()
w = re.compile("\w+",re.I)

def label_sentences(df, input_point):
    labeled_sentences = []
    list_sen = []
    for index, datapoint in df.iterrows():
        tokenized_words = re.findall(w,datapoint[input_point].lower())
        labeled_sentences.append(TaggedDocument(words=tokenized_words, tags=['SENT_%s' %index]))
        list_sen.append(tokenized_words)
    return labeled_sentences, list_sen

def train_doc2vec_model(labeled_sentences):
    model = Doc2Vec(min_count=1, window=9, vector_size=512, sample=1e-4, negative=5, workers=7)
    model.build_vocab(labeled_sentences)
    pretrained_weights = model.wv.vectors
    vocab_size, embedding_size = pretrained_weights.shape
    model.train(labeled_sentences, total_examples=vocab_size, epochs=400)
    
    return model

# %%
textData = df['stemmed_text_data'].to_frame().reset_index()
sen, corpus = label_sentences(textData, 'stemmed_text_data')

# %%
# Training the Doc2Vec model
doc2vec_model = train_doc2vec_model(sen)
# Out:
# WARNING:gensim.models.base_any2vec:EPOCH - 1 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 2 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 3 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 4 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 5 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 6 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 7 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 8 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 9 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 10 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 11 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 12 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 13 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 14 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 15 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 16 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 17 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 18 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 19 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 20 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 21 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 22 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 23 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 24 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 25 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 26 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 27 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 28 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 29 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 30 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 31 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 32 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 33 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 34 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 35 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 36 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 37 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 38 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 39 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 40 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 41 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 42 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 43 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 44 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 45 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 46 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 47 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 48 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 49 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 50 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 51 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 52 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 53 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 54 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 55 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 56 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 57 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 58 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 59 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 60 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 61 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 62 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 63 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 64 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 65 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 66 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 67 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 68 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 69 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 70 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 71 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 72 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 73 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 74 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 75 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 76 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 77 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 78 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 79 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 80 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 81 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 82 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 83 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 84 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 85 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 86 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 87 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 88 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 89 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 90 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 91 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 92 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 93 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 94 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 95 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 96 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 97 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 98 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 99 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 100 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 101 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 102 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 103 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 104 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 105 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 106 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 107 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 108 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 109 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 110 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 111 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 112 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 113 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 114 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 115 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 116 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 117 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 118 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 119 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 120 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 121 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 122 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 123 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 124 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 125 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 126 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 127 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 128 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 129 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 130 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 131 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 132 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 133 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 134 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 135 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 136 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 137 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 138 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 139 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 140 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 141 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 142 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 143 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 144 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 145 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 146 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 147 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 148 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 149 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 150 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 151 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 152 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 153 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 154 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 155 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 156 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 157 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 158 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 159 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 160 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 161 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 162 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 163 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 164 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 165 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 166 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 167 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 168 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 169 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 170 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 171 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 172 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 173 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 174 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 175 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 176 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 177 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 178 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 179 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 180 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 181 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 182 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 183 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 184 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 185 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 186 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 187 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 188 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 189 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 190 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 191 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 192 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 193 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 194 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 195 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 196 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 197 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 198 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 199 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 200 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 201 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 202 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 203 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 204 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 205 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 206 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 207 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 208 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 209 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 210 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 211 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 212 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 213 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 214 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 215 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 216 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 217 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 218 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 219 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 220 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 221 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 222 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 223 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 224 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 225 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 226 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 227 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 228 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 229 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 230 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 231 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 232 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 233 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 234 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 235 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 236 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 237 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 238 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 239 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 240 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 241 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 242 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 243 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 244 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 245 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 246 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 247 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 251 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 252 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 253 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 254 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 255 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 256 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 257 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 258 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 259 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 260 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 261 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 262 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 263 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 264 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 265 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 266 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 267 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 268 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 269 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 270 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 271 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 272 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 273 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 274 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 275 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 276 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 277 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 278 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 279 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 280 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 281 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 282 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 283 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 284 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 285 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 286 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 287 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 288 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 289 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 290 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 291 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 292 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 293 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 294 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 295 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 296 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 297 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 298 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 299 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 300 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 301 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 302 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 303 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 304 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 305 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 306 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 307 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 308 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 309 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 310 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 311 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 312 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 313 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 314 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 315 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 316 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 317 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 318 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 319 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 320 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 321 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 322 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 323 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 324 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 325 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 326 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 327 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 328 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 329 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 330 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 331 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 332 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 333 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 334 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 335 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 336 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 337 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 338 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 339 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 340 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 341 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 342 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 343 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 344 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 345 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 346 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 347 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 348 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 349 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 350 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 351 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 352 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 353 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 354 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 355 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 356 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 357 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 358 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 359 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 360 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 361 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 362 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 363 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 364 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 365 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 366 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 367 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 368 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 369 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 370 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 371 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 372 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 373 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 374 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 375 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 376 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 377 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 378 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 379 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 380 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 381 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 382 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 383 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 384 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 385 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 386 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 387 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 388 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 389 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 390 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 391 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 392 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 393 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 394 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 395 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 396 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 397 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 398 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 399 : supplied example count (1600) did not equal expected count (6269)
# WARNING:gensim.models.base_any2vec:EPOCH - 400 : supplied example count (1600) did not equal expected count (6269)

# %%
# Saving the Doc2Vec model
doc2vec_model.save("doc2vec_model_opinion_corpus.d2v")

# %%
# Loading the Doc2Vec model
doc2vec_model = Doc2Vec.load("doc2vec_model_opinion_corpus.d2v")

# %%
# Further vectorizing the data
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

tfidf1 = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False, ngram_range=(1,1))
result_train1 = tfidf1.fit_transform(corpus)

tfidf2 = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False, ngram_range=(1,2))
result_train2 = tfidf2.fit_transform(corpus)

tfidf3 = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False, ngram_range=(1,3))
result_train3 = tfidf3.fit_transform(corpus)

svd = TruncatedSVD(n_components=512, n_iter=40, random_state=34)
tfidf_data1 = svd.fit_transform(result_train1)
tfidf_data2 = svd.fit_transform(result_train2)
tfidf_data3 = svd.fit_transform(result_train3)

# %%
# Performing POS tagging on the data
from sklearn.feature_extraction.text import CountVectorizer
import spacy

nlp = spacy.blank('en')
temp_textData = pd.DataFrame(list(df['text']))

overall_pos_tags_tokens = []
overall_pos = []
overall_tokens = []
overall_dep = []

for i in range(1600):
    doc = nlp(temp_textData[0][i])
    given_pos_tags_tokens = []
    given_pos = []
    given_tokens = []
    given_dep = []
    for token in doc:
        output = "%s_%s" % (token.pos_, token.tag_)
        given_pos_tags_tokens.append(output)
        given_pos.append(token.pos_)
        given_tokens.append(token.tag_)
        given_dep.append(token.dep_)
        
    overall_pos_tags_tokens.append(given_pos_tags_tokens)
    overall_pos.append(given_pos)
    overall_tokens.append(given_tokens)
    overall_dep.append(given_dep)

# %%
# Normalizing the data
from sklearn.preprocessing import MinMaxScaler

count = CountVectorizer(tokenizer=lambda i:i, lowercase=False)
pos_tags_data = count.fit_transform(overall_pos_tags_tokens).todense()
pos_data = count.fit_transform(overall_pos).todense()
tokens_data = count.fit_transform(overall_tokens).todense()
dep_data = count.fit_transform(overall_dep).todense()
min_max_scaler = MinMaxScaler()
normalized_pos_tags_data = min_max_scaler.fit_transform(pos_tags_data)
normalized_pos_data = min_max_scaler.fit_transform(pos_data)
normalized_tokens_data = min_max_scaler.fit_transform(tokens_data)
normalized_dep_data = min_max_scaler.fit_transform(dep_data)

final_pos_tags_data = np.zeros(shape=(1600, 512)).astype(np.float32)
final_pos_data = np.zeros(shape=(1600, 512)).astype(np.float32)
final_tokens_data = np.zeros(shape=(1600, 512)).astype(np.float32)
final_dep_data = np.zeros(shape=(1600, 512)).astype(np.float32)
final_pos_tags_data[:normalized_pos_tags_data.shape[0],:normalized_pos_tags_data.shape[1]] = normalized_pos_tags_data
final_pos_data[:normalized_pos_data.shape[0],:normalized_pos_data.shape[1]] = normalized_pos_data
final_tokens_data[:normalized_tokens_data.shape[0],:normalized_tokens_data.shape[1]] = normalized_tokens_data
final_dep_data[:normalized_dep_data.shape[0],:normalized_dep_data.shape[1]] = normalized_dep_data
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,

# %%
# Finding max no of words for each review
maxlength = []
for i in range(0,len(sen)):
    maxlength.append(len(sen[i][0]))
    
print(max(maxlength))
# Out:
# 370

# %%
# Function to vectorize
def vectorize_comments(df,d2v_model):
    y = []
    comments = []
    for i in range(0,df.shape[0]):
        label = 'SENT_%s' %i
        comments.append(d2v_model.docvecs[label])
    df['vectorized_comments'] = comments
    
    return df

textData = vectorize_comments(textData,doc2vec_model)
print (textData.head(2))
# Out:
#    index                                  stemmed_text_data  \
# 0      0  stay night getaway famili thursday tripl aaa r...
# 1      1  tripl rate upgrad view room less $ includ brea...
#
#                                  vectorized_comments
# 0  [-0.7275318, -0.22649938, -0.6235039, -0.85056...
# 1  [0.155687, 0.22251926, -1.0280952, 0.015529211...

# %%
# Loading GloVe embedding into the system
embeddings_index = dict()
f = open('/content/drive/MyDrive/Practicum/glove.6B.300d.txt', encoding="utf8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()
print('Loaded %s word vectors.' % len(embeddings_index))
# Out:
# Loaded 400000 word vectors.

# %%
# Vectorizing the reviews using GloVe
from nltk.corpus import stopwords

glove_data = np.zeros(shape=(1600, 800, 512)).astype(np.float32)
temp_textData = df['text'].to_frame().reset_index()
sen2, corpus2 = label_sentences(temp_textData, 'text')
stop_words = set(stopwords.words('english'))
test_word = np.zeros(512).astype(np.float32)
final_matrix = np.zeros(512).astype(np.float32)
final_sizes = []

count = True

for i in range(1600):
    for j in sen2[i][0]:
        if j in embeddings_index and j not in stop_words:
            test_word[:300] = embeddings_index[j]
            if count == True:
                final_matrix = test_word
                count = False
            else:
                final_matrix = np.vstack((final_matrix, test_word))
            
    final_sizes.append(final_matrix.shape[0])
    final_matrix = np.zeros(512).astype(np.float32)
    glove_data[i,:final_matrix.shape[0],:] = final_matrix
    count = True
    
print(max(final_sizes))
# Out:
# 389

# %%
# Splitting the reviews into train-test split randomly
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
X_train, X_test, y_train, y_test = train_test_split(textData["vectorized_comments"].T.tolist(), 
                                                                     dummy_y, 
                                                                     test_size=0.1, 
                                                                     random_state=56)

# %%
# Reshaping the vectorized data to fit the input of the model
X = np.array(textData["vectorized_comments"].T.tolist()).reshape((1,1600,512))
y = np.array(dummy_y).reshape((1600,4))
X_train2 = np.array(X_train).reshape((1,1440,512))
y_train2 = np.array(y_train).reshape((1,1440,4))
X_test2 = np.array(X_test).reshape((1,160,512))
y_test2 = np.array(y_test).reshape((1,160,4))

# %%
# Stratified K fold repeated 10 times for cross validation
from sklearn.model_selection import StratifiedKFold
Xtemp = textData["vectorized_comments"].T.tolist()
ytemp = df['given_class']
training_indices = []
testing_indices = []

skf = StratifiedKFold(n_splits=10)
skf.get_n_splits(Xtemp, ytemp)

for train_index, test_index in skf.split(Xtemp, ytemp):
    training_indices.append(train_index)
    testing_indices.append(test_index)

# %%
def extractTrainingAndTestingData(givenIndex):
    X_train3 = np.zeros(shape=(1440, max(maxlength)+10+379, 512)).astype(np.float32)
    Y_train3 = np.zeros(shape=(1440, 4)).astype(np.float32)
    X_test3 = np.zeros(shape=(160, max(maxlength)+10+379, 512)).astype(np.float32)
    Y_test3 = np.zeros(shape=(160, 4)).astype(np.float32)

    empty_word = np.zeros(512).astype(np.float32)

    count_i = 0
    for i in training_indices[givenIndex]:
        len1 = len(sen[i][0])
        average_vector1 = np.zeros(512).astype(np.float32)
        average_vector2 = np.zeros(512).astype(np.float32)
        average_vector3 = np.zeros(512).astype(np.float32)
        for j in range(max(maxlength)+10+379):
            if j < len1:
                X_train3[count_i,j,:] = doc2vec_model[sen[i][0][j]]
                average_vector1 += result_train1[i, tfidf1.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
                average_vector2 += result_train2[i, tfidf2.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
                average_vector3 += result_train3[i, tfidf3.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
            elif j >= len1 and j < len1 + 379:
                X_train3[count_i,j,:] = glove_data[i, j-len1, :]
            elif j == len1 + 379:
                X_train3[count_i,j,:] = tfidf_data1[i]
            elif j == len1 + 380:
                X_train3[count_i,j,:] = tfidf_data2[i]
            elif j == len1+381:
                X_train3[count_i,j,:] = tfidf_data3[i]
            elif j == len1+382:
                X_train3[count_i,j,:] = average_vector1
            elif j == len1+383:
                X_train3[count_i,j,:] = average_vector2
            elif j == len1+384:
                X_train3[count_i,j,:] = average_vector3
            elif j == len1+385:
                X_train3[count_i,j,:] = final_pos_tags_data[i] 
            elif j == len1+386:
                X_train3[count_i,j,:] = final_pos_data[i]
            elif j == len1+387:
                X_train3[count_i,j,:] = final_tokens_data[i]
            elif j == len1+388:
                X_train3[count_i,j,:] = final_dep_data[i]
            else:
                X_train3[count_i,j,:] = empty_word

        Y_train3[count_i,:] = dummy_y[i]
        count_i += 1


    count_i = 0
    for i in testing_indices[givenIndex]:
        len1 = len(sen[i][0])
        average_vector1 = np.zeros(512).astype(np.float32)
        average_vector2 = np.zeros(512).astype(np.float32)
        average_vector3 = np.zeros(512).astype(np.float32)
        for j in range(max(maxlength)+10+379):
            if j < len1:
                X_test3[count_i,j,:] = doc2vec_model[sen[i][0][j]]
                average_vector1 += result_train1[i, tfidf1.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
                average_vector2 += result_train2[i, tfidf2.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]  
                average_vector3 += result_train3[i, tfidf3.vocabulary_[sen[i][0][j]]] * doc2vec_model[sen[i][0][j]]
            elif j >= len1 and j < len1 + 379:
                X_test3[count_i,j,:] = glove_data[i, j-len1, :]
            elif j == len1 + 379:
                X_test3[count_i,j,:] = tfidf_data1[i]
            elif j == len1 + 380:
                X_test3[count_i,j,:] = tfidf_data2[i]
            elif j == len1+381:
                X_test3[count_i,j,:] = tfidf_data3[i]
            elif j == len1+382:
                X_test3[count_i,j,:] = average_vector1
            elif j == len1+383:
                X_test3[count_i,j,:] = average_vector2
            elif j == len1+384:
                X_test3[count_i,j,:] = average_vector3
            elif j == len1+385:
                X_test3[count_i,j,:] = final_pos_tags_data[i]
            elif j == len1+386:
                X_test3[count_i,j,:] = final_pos_data[i]
            elif j == len1+387:
                X_test3[count_i,j,:] = final_tokens_data[i]
            elif j == len1+388:
                X_test3[count_i,j,:] = final_dep_data[i]
            else:
                X_test3[count_i,j,:] = empty_word

        Y_test3[count_i,:] = dummy_y[i]
        count_i += 1
        
    return X_train3, X_test3, Y_train3, Y_test3

# %%
# Setting the layers of CNN-BiLSTM model and training the model
model = Sequential()
# Changing Activation Functions as required for the model
#model.add(Conv1D(filters=128, kernel_size=5, padding='same', activation='relu', input_shape=(max(maxlength)+10+379,512)))
#model.add(Conv1D(filters=128, kernel_size=5, padding='same', activation='selu', input_shape=(max(maxlength)+10+379,512)))
#model.add(Conv1D(filters=128, kernel_size=5, padding='same', activation='swish', input_shape=(max(maxlength)+10+379,512)))
#model.add(Conv1D(filters=128, kernel_size=5, padding='same', activation='sigmoid', input_shape=(max(maxlength)+10+379,512)))
model.add(Conv1D(filters=128, kernel_size=5, padding='same', activation='tanh', input_shape=(max(maxlength)+10+379,512)))
model.add(Dropout(0.25))
model.add(MaxPooling1D(pool_size=2))
model.add(Dropout(0.25))
# Removing layers as the required output is achieved and computational power is reduced
#model.add(Conv1D(filters=32, kernel_size=7, padding='same', activation='tanh'))
#model.add(Dropout(0.25))
#model.add(MaxPooling1D(pool_size=2))
#model.add(Dropout(0.25))

model.add(Bidirectional(LSTM(50, dropout=0.25, recurrent_dropout=0.2)))
model.add(Dense(4, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 759, 128)          327808
#
#  dropout (Dropout)           (None, 759, 128)          0
#
#  max_pooling1d (MaxPooling1D  (None, 379, 128)         0
#  )
#
#  dropout_1 (Dropout)         (None, 379, 128)          0
#
#  bidirectional (Bidirectiona  (None, 100)              71600
#  l)
#
#  dense (Dense)               (None, 4)                 404
#
# =================================================================
# Total params: 399,812
# Trainable params: 399,812
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Running the model and calculating the accuracy, loss, validation accuracy and validation loss at each iteration, each epoch
from sklearn.metrics import accuracy_score
from keras.callbacks import ModelCheckpoint 

final_accuracies = []

for i in range(4):
    filename = 'weights.best.from_scratch%s.hdf5' % i
    checkpointer = ModelCheckpoint(filepath=filename, verbose=1, save_best_only=True)
    X_train3, X_test3, Y_train3, Y_test3 = extractTrainingAndTestingData(i)
    model.fit(X_train3, Y_train3, epochs=10, batch_size=512, callbacks=[checkpointer], validation_data=(X_test3, Y_test3))
    model.load_weights(filename)
    predicted = np.rint(model.predict(X_test3))
    final_accuracies.append(accuracy_score(Y_test3, predicted))
    print(accuracy_score(Y_test3, predicted))
# Out:
# Epoch 1/10
# 3/3 [==============================] - ETA: 0s - loss: 0.6370 - accuracy: 0.2715
# Epoch 1: val_loss improved from inf to 0.55657, saving model to weights.best.from_scratch0.hdf5
# 3/3 [==============================] - 33s 5s/step - loss: 0.6370 - accuracy: 0.2715 - val_loss: 0.5566 - val_accuracy: 0.4187
# Epoch 2/10
# 3/3 [==============================] - ETA: 0s - loss: 0.5534 - accuracy: 0.3958
# Epoch 2: val_loss improved from 0.55657 to 0.52720, saving model to weights.best.from_scratch0.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.5534 - accuracy: 0.3958 - val_loss: 0.5272 - val_accuracy: 0.4938
# Epoch 3/10
# 3/3 [==============================] - ETA: 0s - loss: 0.5243 - accuracy: 0.5389
# Epoch 3: val_loss improved from 0.52720 to 0.49453, saving model to weights.best.from_scratch0.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.5243 - accuracy: 0.5389 - val_loss: 0.4945 - val_accuracy: 0.5375
# Epoch 4/10
# 3/3 [==============================] - ETA: 0s - loss: 0.4948 - accuracy: 0.6021
# Epoch 4: val_loss improved from 0.49453 to 0.45081, saving model to weights.best.from_scratch0.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.4948 - accuracy: 0.6021 - val_loss: 0.4508 - val_accuracy: 0.6687
# Epoch 5/10
# 3/3 [==============================] - ETA: 0s - loss: 0.4502 - accuracy: 0.7132
# Epoch 5: val_loss improved from 0.45081 to 0.40724, saving model to weights.best.from_scratch0.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.4502 - accuracy: 0.7132 - val_loss: 0.4072 - val_accuracy: 0.7437
# Epoch 6/10
# 3/3 [==============================] - ETA: 0s - loss: 0.4069 - accuracy: 0.7604
# Epoch 6: val_loss improved from 0.40724 to 0.36275, saving model to weights.best.from_scratch0.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.4069 - accuracy: 0.7604 - val_loss: 0.3627 - val_accuracy: 0.7937
# Epoch 7/10
# 3/3 [==============================] - ETA: 0s - loss: 0.3645 - accuracy: 0.8160
# Epoch 7: val_loss improved from 0.36275 to 0.32480, saving model to weights.best.from_scratch0.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.3645 - accuracy: 0.8160 - val_loss: 0.3248 - val_accuracy: 0.8125
# Epoch 8/10
# 3/3 [==============================] - ETA: 0s - loss: 0.3292 - accuracy: 0.8264
# Epoch 8: val_loss improved from 0.32480 to 0.30189, saving model to weights.best.from_scratch0.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.3292 - accuracy: 0.8264 - val_loss: 0.3019 - val_accuracy: 0.8313
# Epoch 9/10
# 3/3 [==============================] - ETA: 0s - loss: 0.2952 - accuracy: 0.8444
# Epoch 9: val_loss improved from 0.30189 to 0.28185, saving model to weights.best.from_scratch0.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.2952 - accuracy: 0.8444 - val_loss: 0.2818 - val_accuracy: 0.8250
# Epoch 10/10
# 3/3 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.8562
# Epoch 10: val_loss improved from 0.28185 to 0.26252, saving model to weights.best.from_scratch0.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.2648 - accuracy: 0.8562 - val_loss: 0.2625 - val_accuracy: 0.8375
# 0.83125
# Epoch 1/10
# 3/3 [==============================] - ETA: 0s - loss: 0.2455 - accuracy: 0.8604
# Epoch 1: val_loss improved from inf to 0.18018, saving model to weights.best.from_scratch1.hdf5
# 3/3 [==============================] - 13s 4s/step - loss: 0.2455 - accuracy: 0.8604 - val_loss: 0.1802 - val_accuracy: 0.9062
# Epoch 2/10
# 3/3 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.8667
# Epoch 2: val_loss did not improve from 0.18018
# 3/3 [==============================] - 12s 4s/step - loss: 0.2272 - accuracy: 0.8667 - val_loss: 0.1970 - val_accuracy: 0.8562
# Epoch 3/10
# 3/3 [==============================] - ETA: 0s - loss: 0.2133 - accuracy: 0.8632
# Epoch 3: val_loss improved from 0.18018 to 0.15401, saving model to weights.best.from_scratch1.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.2133 - accuracy: 0.8632 - val_loss: 0.1540 - val_accuracy: 0.9062
# Epoch 4/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.8931
# Epoch 4: val_loss did not improve from 0.15401
# 3/3 [==============================] - 12s 4s/step - loss: 0.1945 - accuracy: 0.8931 - val_loss: 0.1698 - val_accuracy: 0.8687
# Epoch 5/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1816 - accuracy: 0.8986
# Epoch 5: val_loss improved from 0.15401 to 0.14775, saving model to weights.best.from_scratch1.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.1816 - accuracy: 0.8986 - val_loss: 0.1477 - val_accuracy: 0.8938
# Epoch 6/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1694 - accuracy: 0.9062
# Epoch 6: val_loss did not improve from 0.14775
# 3/3 [==============================] - 12s 4s/step - loss: 0.1694 - accuracy: 0.9062 - val_loss: 0.1533 - val_accuracy: 0.9125
# Epoch 7/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9167
# Epoch 7: val_loss improved from 0.14775 to 0.13803, saving model to weights.best.from_scratch1.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.1558 - accuracy: 0.9167 - val_loss: 0.1380 - val_accuracy: 0.8938
# Epoch 8/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1482 - accuracy: 0.9132
# Epoch 8: val_loss did not improve from 0.13803
# 3/3 [==============================] - 12s 4s/step - loss: 0.1482 - accuracy: 0.9132 - val_loss: 0.1519 - val_accuracy: 0.8813
# Epoch 9/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.9229
# Epoch 9: val_loss did not improve from 0.13803
# 3/3 [==============================] - 12s 4s/step - loss: 0.1383 - accuracy: 0.9229 - val_loss: 0.1447 - val_accuracy: 0.8875
# Epoch 10/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1269 - accuracy: 0.9410
# Epoch 10: val_loss did not improve from 0.13803
# 3/3 [==============================] - 12s 4s/step - loss: 0.1269 - accuracy: 0.9410 - val_loss: 0.1442 - val_accuracy: 0.8813
# 0.89375
# Epoch 1/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9271
# Epoch 1: val_loss improved from inf to 0.14286, saving model to weights.best.from_scratch2.hdf5
# 3/3 [==============================] - 13s 4s/step - loss: 0.1442 - accuracy: 0.9271 - val_loss: 0.1429 - val_accuracy: 0.9187
# Epoch 2/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1337 - accuracy: 0.9333
# Epoch 2: val_loss did not improve from 0.14286
# 3/3 [==============================] - 12s 4s/step - loss: 0.1337 - accuracy: 0.9333 - val_loss: 0.1455 - val_accuracy: 0.9187
# Epoch 3/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9361
# Epoch 3: val_loss did not improve from 0.14286
# 3/3 [==============================] - 12s 4s/step - loss: 0.1221 - accuracy: 0.9361 - val_loss: 0.1461 - val_accuracy: 0.9125
# Epoch 4/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1189 - accuracy: 0.9431
# Epoch 4: val_loss improved from 0.14286 to 0.14134, saving model to weights.best.from_scratch2.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.1189 - accuracy: 0.9431 - val_loss: 0.1413 - val_accuracy: 0.9250
# Epoch 5/10
# 3/3 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9535
# Epoch 5: val_loss improved from 0.14134 to 0.14060, saving model to weights.best.from_scratch2.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.1072 - accuracy: 0.9535 - val_loss: 0.1406 - val_accuracy: 0.9187
# Epoch 6/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9569
# Epoch 6: val_loss improved from 0.14060 to 0.13438, saving model to weights.best.from_scratch2.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.0981 - accuracy: 0.9569 - val_loss: 0.1344 - val_accuracy: 0.9250
# Epoch 7/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9646
# Epoch 7: val_loss did not improve from 0.13438
# 3/3 [==============================] - 12s 4s/step - loss: 0.0890 - accuracy: 0.9646 - val_loss: 0.1392 - val_accuracy: 0.9125
# Epoch 8/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0883 - accuracy: 0.9625
# Epoch 8: val_loss did not improve from 0.13438
# 3/3 [==============================] - 12s 4s/step - loss: 0.0883 - accuracy: 0.9625 - val_loss: 0.1417 - val_accuracy: 0.9062
# Epoch 9/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9618
# Epoch 9: val_loss did not improve from 0.13438
# 3/3 [==============================] - 12s 4s/step - loss: 0.0798 - accuracy: 0.9618 - val_loss: 0.1499 - val_accuracy: 0.8938
# Epoch 10/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9694
# Epoch 10: val_loss did not improve from 0.13438
# 3/3 [==============================] - 12s 4s/step - loss: 0.0756 - accuracy: 0.9694 - val_loss: 0.1539 - val_accuracy: 0.8813
# 0.925
# Epoch 1/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0934 - accuracy: 0.9569
# Epoch 1: val_loss improved from inf to 0.08189, saving model to weights.best.from_scratch3.hdf5
# 3/3 [==============================] - 14s 4s/step - loss: 0.0934 - accuracy: 0.9569 - val_loss: 0.0819 - val_accuracy: 0.9625
# Epoch 2/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9611
# Epoch 2: val_loss improved from 0.08189 to 0.07216, saving model to weights.best.from_scratch3.hdf5
# 3/3 [==============================] - 12s 4s/step - loss: 0.0872 - accuracy: 0.9611 - val_loss: 0.0722 - val_accuracy: 0.9750
# Epoch 3/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0837 - accuracy: 0.9597
# Epoch 3: val_loss did not improve from 0.07216
# 3/3 [==============================] - 12s 4s/step - loss: 0.0837 - accuracy: 0.9597 - val_loss: 0.0777 - val_accuracy: 0.9625
# Epoch 4/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9736
# Epoch 4: val_loss did not improve from 0.07216
# 3/3 [==============================] - 12s 4s/step - loss: 0.0746 - accuracy: 0.9736 - val_loss: 0.0783 - val_accuracy: 0.9688
# Epoch 5/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9722
# Epoch 5: val_loss did not improve from 0.07216
# 3/3 [==============================] - 12s 4s/step - loss: 0.0692 - accuracy: 0.9722 - val_loss: 0.0798 - val_accuracy: 0.9625
# Epoch 6/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9722
# Epoch 6: val_loss did not improve from 0.07216
# 3/3 [==============================] - 12s 4s/step - loss: 0.0662 - accuracy: 0.9722 - val_loss: 0.0778 - val_accuracy: 0.9625
# Epoch 7/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9785
# Epoch 7: val_loss did not improve from 0.07216
# 3/3 [==============================] - 12s 4s/step - loss: 0.0613 - accuracy: 0.9785 - val_loss: 0.0781 - val_accuracy: 0.9563
# Epoch 8/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0591 - accuracy: 0.9799
# Epoch 8: val_loss did not improve from 0.07216
# 3/3 [==============================] - 12s 4s/step - loss: 0.0591 - accuracy: 0.9799 - val_loss: 0.0823 - val_accuracy: 0.9563
# Epoch 9/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9826
# Epoch 9: val_loss did not improve from 0.07216
# 3/3 [==============================] - 12s 4s/step - loss: 0.0554 - accuracy: 0.9826 - val_loss: 0.0838 - val_accuracy: 0.9563
# Epoch 10/10
# 3/3 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9750
# Epoch 10: val_loss did not improve from 0.07216
# 3/3 [==============================] - 12s 4s/step - loss: 0.0570 - accuracy: 0.9750 - val_loss: 0.0977 - val_accuracy: 0.9250
# 0.975

# %%
print(sum(final_accuracies) / len(final_accuracies)*100,"%")
# Out:
# 90.62500000000001 %
